# %% [markdown]
# <a href="https://colab.research.google.com/github/shsimmu2006-crypto/my-first/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list=[10, 20, 30, 40, 50]
print("list elements:", my_list)
# Out:
# list elements: [10, 20, 30, 40, 50]

# %%
numbers = [1, 2, 3, 4]
numbers.append(5)      # Add element
numbers.remove(2)      # Remove element
print("Updated list:", numbers)
# Out:
# Updated list: [1, 3, 4, 5]

# %%
my_list = [10, 20, 30, 40, 50]
print("List elements:", my_list)
# Out:
# List elements: [10, 20, 30, 40, 50]

# %%
numbers = [1, 2, 3, 4]
numbers.append(5)
numbers.remove(2)
print("Updated list:", numbers)
# Out:
# Updated list: [1, 3, 4, 5]

# %%
nums = [5, 9, 2, 8, 1]
print("Maximum:", max(nums))
print("Minimum:", min(nums))
# Out:
# Maximum: 9
# Minimum: 1

# %%
nums = [10, 20, 30, 40, 50]
reversed_list = nums[::-1]
print("Reversed list:", reversed_list)
# Out:
# Reversed list: [50, 40, 30, 20, 10]

# %%
items = [1, 2, 2, 3, 3, 3, 4]
freq = {}
for i in items:
    freq[i] = freq.get(i, 0) + 1
print("Frequency of elements:", freq)
# Out:
# Frequency of elements: {1: 1, 2: 2, 3: 3, 4: 1}

# %%
text = input("Enter a string: ")
vowels = "aeiouAEIOU"
count = 0
for ch in text:
    if ch in vowels:
        count += 1
print("Number of vowels:", count)
# Out:
# Enter a string: simran
# Number of vowels: 2

# %%
+s = input("Enter a string: ")
if s == s[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a string: yayay
# Palindrome

# %%
import string
text = input("Enter a string: ")
no_punct = ""
for ch in text:
    if ch not in string.punctuation:
        no_punct += ch
print("String without punctuation:", no_punct)
# Out:
# Enter a string: run.
# String without punctuation: run

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()
longest = max(words, key=len)
print("Longest word:", longest)
# Out:
# Enter a sentence: you're weird
# Longest word: you're

# %%
f = open("example.txt", "w")
f.write("Hello! This is a sample text file.\nWelcome to Python file handling.")
f.close()
print("File created and content written successfully.")
# Out:
# File created and content written successfully.

# %%
f = open("example.txt", "r")
content = f.read()
print("File content:\n", content)
f.close()
# Out:
# File content:
#  Hello! This is a sample text file.
# Welcome to Python file handling.

# %%
f = open("example.txt", "a")
f.write("\nThis line is appended to the file.")
f.close()
print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
f = open("example.txt", "r")
lines = f.readlines()
print("Number of lines:", len(lines))
f.close()
# Out:
# Number of lines: 3

# %%
f = open("example.txt", "r")
text = f.read()
words = text.split()
freq = {}
for word in words:
    freq[word] = freq.get(word, 0) + 1
print("Word frequency:", freq)
f.close()
# Out:
# Word frequency: {'Hello!': 1, 'This': 2, 'is': 2, 'a': 1, 'sample': 1, 'text': 1, 'file.': 2, 'Welcome': 1, 'to': 2, 'Python': 1, 'file': 1, 'handling.': 1, 'line': 1, 'appended': 1, 'the': 1}

# %%
src = open("example.txt", "r")
dest = open("copy.txt", "w")
for line in src:
    dest.write(line)
src.close()
dest.close()
print("File copied successfully.")
# Out:
# File copied successfully.
